# %%
# %run -i dp_query_Jobs.py
# Out:
# 2019-08-20 12:21:25
#
#                      Tasks in Jobs table: 0                                                  Snapshot every : 2 seconds
#
# FASTLANE                                           HIGH                                               MEDIUM                                             LOW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2019-08-20 12:21:27
#
#                      Tasks in Jobs table: 0                                                  Snapshot every : 2 seconds
#
# FASTLANE                                           HIGH                                               MEDIUM                                             LOW
# 2019-08-20 12:21:29
#
#                      Tasks in Jobs table: 0                                                  Snapshot every : 2 seconds
#
# FASTLANE                                           HIGH                                               MEDIUM                                             LOW
#
#
#
# ...
